# %% [markdown]
# <a href="https://colab.research.google.com/github/Janies-Garcia-Velasco/simulacion-n-2/blob/main/Metodo_monte_carlo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#biblioteca
import numpy as np
import matplotlib.pyplot as plt
import random as rnd

# %%
#parametros
a=0
b=1

# Número de muestras a generar
n = 100000

# %%
# Función f(x) de la cual queremos generar muestras
def f(x):
  return np.cos((np.pi*x)/2)

#metodo de monte carlo
def MC_media(simulaciones, a,b):

  muestras=np.random.uniform(a,b,simulaciones)

  #evaluamos la funcion de cada simulacion
  valores=f(muestras)

  #media de los valores de la funcion
  media=np.mean(valores)

  #calculo de la integral
  integral=(b-a)*media

  #graficar la funcion y las muestras
  x=np.linspace(a,b,500)
  y=f(x)
  plt.plot(x,y,label="funcion", color="blue")

  #graficacion de la ffunción
  plt.scatter(muestras, valores, color= "red")

  plt.title("histmonte carlo, media muestral")
  plt.xlabel("x")
  plt.ylabel("f(x)")
  plt.grid(True)
  plt.show

  return integral

# %%
#ejecucion del metodo monte carlo
integral=MC_media(n,a,b)

print("estimacion de la integral: ", integral)
# Out:
# estimacion de la integral:  0.6352117520448338
