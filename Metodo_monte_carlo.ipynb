# %% [markdown]
# <a href="https://colab.research.google.com/github/Janies-Garcia-Velasco/simulacion-n-2/blob/main/Metodo_monte_carlo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#bibliotecas
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
#parametros de la integral
a=0
b=1

def g(x):
  return np.cos((np.pi*x)/2)

#numero que queremos generar
N=100

# %%
#generacion de puntos aleatorios
x2=np.random.uniform(a,b,N)
y2=np.random.uniform(0,1,100)

#aceptacion de puntos
aceptado= y2 <= g(x2)

# %%
#grafiacion de los puntos
plt.figure(figsize=(10,6))
plt.plot(x2[aceptado],y2[aceptado], "go", markersize=2, label="puntos aceptados")
plt.plot(x2[~aceptado],y2[~aceptado], "ro", markersize=2, label="puntos rechazados")

#grafica de la curvatura
x_curva=np.linspace(a,b,N)
plt.plot(x_curva, np.cos((np.pi * x_curva) / 2), "b-", label="f(x)=cos(πx/2)")
plt.title('Monte Carlo - Método de Aceptación y Rechazo')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
